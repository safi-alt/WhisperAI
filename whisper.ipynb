# %% [markdown]
# <a href="https://colab.research.google.com/github/safi-alt/WhisperAI/blob/main/whisper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install git+https://github.com/openai/whisper
# Out:
# Collecting git+https://github.com/openai/whisper
#   Cloning https://github.com/openai/whisper to /tmp/pip-req-build-lv1xky_a
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper /tmp/pip-req-build-lv1xky_a
#   Resolved https://github.com/openai/whisper to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (0.58.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (1.23.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (2.1.0+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (4.66.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (10.1.0)
# Collecting tiktoken (from openai-whisper==20231117)
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 12.5 MB/s eta 0:00:00
# Requirement already satisfied: triton<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (2.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from triton<3,>=2.0.0->openai-whisper==20231117) (3.13.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->openai-whisper==20231117) (0.41.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper==20231117) (2023.12.25)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper==20231117) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (2023.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->openai-whisper==20231117) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->openai-whisper==20231117) (1.3.0)
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20231117-py3-none-any.whl size=802825 sha256=7a9f68096e39712e12eddca6c33913b3661c3f07ddba295f6fab5f8e5cbec7db
#   Stored in directory: /tmp/pip-ephem-wheel-cache-09cx2ypx/wheels/3d/da/23/a3edaa30ff9d841d474be2db3d17e9230a578e81850b82195d
# Successfully built openai-whisper
# Installing collected packages: tiktoken, openai-whisper
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# Successfully installed openai-whisper-20231117 tiktoken-0.6.0

# %%
import whisper
model = whisper.load_model("medium.en")
# Out:
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:19<00:00, 77.5MiB/s]

# %%
# Transcribe the audio file
transcription = model.transcribe("transcribe.mp4", language="english")

# Specify the path to store the transcribed text file
output_file_path = "transcribed_output.txt"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-053c233867d7> in <cell line: 8>()
#       7 # Write the transcribed text to a text file
#       8 with open(output_file_path, "w", encoding="utf-8") as output_file:
# ----> 9     output_file.write(transcription)
#      10
#      11 print(f"Transcription saved to: {output_file_path}")
#
# TypeError: write() argument must be str, not dict

# %%
# Extract the transcribed text from the result dictionary
transcription = result["text"]
print(transcription)
# Out:
#  Who's the carer? Is it your mum or dad? It's my mum. Yeah, yeah, yeah, sorry. It's my mum. It's your mum, okay, right. And how long have you been the carer for her? On that particular condition? On that particular condition. Roughly, just even rough? Probably about five years. Five years, okay, that's great. And you obviously stayed with his friend for sure, that's fine, so I've got all those easy ones. That's great, thank you very much for that. So I'm going to, as I said, go on and ask you a set of questions. Obviously, you know, give me as much detail as you possibly can, but obviously feel free to opt out of any questions that you don't feel like answering. One thing I don't want to do is get you emotional or anything discussing it, because I know what the issue is like, you know, my mum and father both passed away with the same condition. Okay. Literally four or five years ago, so it's quite a tough situation to live with, but you know. So, the first question I wanted to ask was, what motivated you to assume the role of caregiver for your loved one? You know, what has it kind of drove you to become the carer? I suppose, well, we're a family of ten. Yeah, shall we? Yeah, I haven't done that. Most are married and separated in their own homes, but even men, like over a period of time, my younger siblings, so I'm towards the younger end of the ten. Oh, right, okay. So, what we've done is that, I think it was just partly, I'm the one that was still at home anyway, so it was a natural sort of situation to fall into. However, it's probably stopped me from, you know, kind of branching out and maybe actively exploring other avenues in my own life. Because of dedication to my mum, my mum's dedicated her whole life selflessly to us, and it's just, I couldn't think of anything else, or anyone else kind of doing it, so I mean, it's an honour and privilege is how I perceive it. But yeah. So, did you think, there's more a kind of sense of moral duty then, maybe? Yeah, I would say, like it's a, certainly, like obviously faith is a huge part of what motivates me. So, certainly faith, knowing that it's an obligation to, you know, to honour and respect your parents, and morally, yeah, I can imagine, I think seeing how much a mum has parented ten children, so just seeing that, and I think the sacrifices she's made in her whole life, to kind of, I don't think we can ever repay our parents, we can just do a service that hopefully is some level of care. So, just, obviously you said religion there, and how important was that, because I'm just wondering, you know, if you weren't religious, would you still kind of... I suppose it's a hard one, I suppose we, maybe actually what we can say is that through our family we have varying degrees of what you would call religiosity, I suppose. But all of us are dedicated to caring for our parents, and our mum as well, so it wouldn't be a case of, I think, with the way, I think primarily, probably the devotion mum's shown, and then obviously what keeps you in it, is knowing that it's also obligated. So, I'm just curious, because obviously you've taken on the role, and I'm just wondering if you hadn't taken on that role, had you quite confident someone else would have taken on the role? Yeah, absolutely, absolutely. Had I not been the primary carer, I would have certainly been a secondary carer, yes, and I think there would have been somebody else who would have been doing primary care. So, how much time do you devote then, kind of on a daily basis, to her care? Mostly, like, so in the mornings, what I'll do is, so my mum's still relatively self-sufficient in that she can still get up and dress and do all those kind of things herself. Hi very much, the issue that she probably does have is not being able to, she won't do anything like cleaning and cooking, well, cleaning she'll still try to do, but cooking and stuff like that. She has to be encouraged to shower and stuff like that, so in the mornings what I d ...

# %%
from tqdm import tqdm

# %%
# Specify the path to store the transcribed text file
output_file_path = "transcribed_output.txt"

# Write the transcribed text to a text file
with open(output_file_path, "w", encoding="utf-8") as output_file:
    # Use tqdm to show the progress bar
    with tqdm(total=len(transcription), desc="Transcribing") as pbar:
        for char in transcription:
            output_file.write(char)
            pbar.update(1)

print(f"Transcription saved to: {output_file_path}")
# Out:
# Transcribing: 100%|██████████| 51642/51642 [00:00<00:00, 1831096.59it/s]
# Transcription saved to: transcribed_output.txt
